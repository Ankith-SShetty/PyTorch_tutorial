# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankith-SShetty/PyTorch_tutorial/blob/master/Learning_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
X = torch.tensor([[1],[2],[3],[4],[5],[6]]).float()

y = torch.tensor([[0],[0],[0],[1],[1],[1]]).float()

# %%
model = nn.Sequential(
    nn.Linear(1,1),
    nn.Sigmoid()
)

loss_fn = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.01)

for epoch in range(1000):
  prediction = model(X)
  loss = loss_fn(prediction, y)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  if epoch%100 == 0:
    print(f"Epoch {epoch}, Loss: {loss}")
# Out:
# Epoch 0, Loss: 0.594142496585846
# Epoch 100, Loss: 0.5413522720336914
# Epoch 200, Loss: 0.5193492770195007
# Epoch 300, Loss: 0.49918612837791443
# Epoch 400, Loss: 0.4806070029735565
# Epoch 500, Loss: 0.46346399188041687
# Epoch 600, Loss: 0.4476219415664673
# Epoch 700, Loss: 0.4329577386379242
# Epoch 800, Loss: 0.41936030983924866
# Epoch 900, Loss: 0.4067295491695404
