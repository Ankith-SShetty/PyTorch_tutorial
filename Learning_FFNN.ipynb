# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankith-SShetty/PyTorch_tutorial/blob/master/Learning_FFNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
X = torch.tensor([[1],[2],[3],[4],[5],[6]]).float()
y = torch.tensor([[0],[0],[0],[1],[1],[1]]).float()

# %%
class SimpleNN(nn.Module):

  def __init__(self):
    super(SimpleNN, self).__init__()
    self.fc1 = nn.Linear(1,4)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(4,1)
    self.sigmoid = nn.Sigmoid()

  def forward(self, X):
    X = self.fc1(X)
    X = self.relu(X)
    X = self.fc2(X)
    X = self.sigmoid(X)
    return X

model = SimpleNN()

loss_fn = nn.BCELoss()
optimizer = optim.SGD(model.parameters(),
                      lr = 0.01)

for epoch in range(1000):
  prediction = model(X)
  loss = loss_fn(prediction, y)

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  if epoch % 100 == 0:
    print(f"Epoch: {epoch}, Loss: {loss}")
# Out:
# Epoch: 0, Loss: 0.6973626613616943
# Epoch: 100, Loss: 0.6348482966423035
# Epoch: 200, Loss: 0.5943688750267029
# Epoch: 300, Loss: 0.5569227337837219
# Epoch: 400, Loss: 0.5214837789535522
# Epoch: 500, Loss: 0.48759743571281433
# Epoch: 600, Loss: 0.4550594985485077
# Epoch: 700, Loss: 0.42384016513824463
# Epoch: 800, Loss: 0.3940337598323822
# Epoch: 900, Loss: 0.3689012825489044
